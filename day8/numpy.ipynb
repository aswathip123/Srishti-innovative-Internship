2 MB/s eta 0:00:02
#    ---------------------- ----------------- 7.0/12.3 MB 3.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 7.1/12.3 MB 3.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 7.2/12.3 MB 3.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 7.4/12.3 MB 3.1 MB/s eta 0:00:02
#    ------------------------ --------------- 7.5/12.3 MB 3.1 MB/s eta 0:00:02
#    ------------------------ --------------- 7.6/12.3 MB 3.1 MB/s eta 0:00:02
#    ------------------------- -------------- 7.8/12.3 MB 3.1 MB/s eta 0:00:02
#    ------------------------- -------------- 8.0/12.3 MB 3.1 MB/s eta 0:00:02
#    -------------------------- ------------- 8.1/12.3 MB 3.1 MB/s eta 0:00:02
#    -------------------------- ------------- 8.3/12.3 MB 3.1 MB/s eta 0:00:02
#    --------------------------- ------------ 8.4/12.3 MB 3.1 MB/s eta 0:00:02
#    --------------------------- ------------ 8.5/12.3 MB 3.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.7/12.3 MB 3.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.9/12.3 MB 3.2 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.2/12.3 MB 3.2 MB/s eta 0:00:01
#    ------------------------------ --------- 9.3/12.3 MB 3.2 MB/s eta 0:00:01
#    ------------------------------ --------- 9.5/12.3 MB 3.2 MB/s eta 0:00:01
#    ------------------------------- -------- 9.7/12.3 MB 3.2 MB/s eta 0:00:01
#    ------------------------------- -------- 9.7/12.3 MB 3.2 MB/s eta 0:00:01
#    -------------------------------- ------- 10.0/12.3 MB 3.2 MB/s eta 0:00:01
#    --------------------------------- ------ 10.2/12.3 MB 3.2 MB/s eta 0:00:01
#    --------------------------------- ------ 10.4/12.3 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.6/12.3 MB 3.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.8/12.3 MB 3.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.9/12.3 MB 3.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.1/12.3 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 11.2/12.3 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------- -- 11.4/12.3 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------- -- 11.6/12.3 MB 3.6 MB/s eta 0:00:01
#    -------------------------------------- - 11.8/12.3 MB 3.6 MB/s eta 0:00:01
#    -------------------------------------- - 11.8/12.3 MB 3.6 MB/s eta 0:00:01
#    -------------------------------------- - 11.9/12.3 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  12.1/12.3 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  12.2/12.3 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.3 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 3.4 MB/s eta 0:00:00
# Installing collected packages: numpy
# Successfully installed numpy-2.4.6
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
# From Python Lists
import numpy as np
arr = np.array([1, 2, 3])
arr_2d = np.array([[1, 2, 3], [4, 5, 6]])
 
# Special Arrays
np.zeros((3, 3))
np.ones((2, 4))
np.eye(3)
np.arange(0, 10, 2)
np.linspace(0, 1, 5)
np.random.rand(3, 2)
np.random.randn(3, 2)
# Out:
# array([[-0.27365916, -0.13434621],
#        [-0.05252066,  0.15888861],
#        [ 1.58490163,  0.86245813]])

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])
print(arr.shape)
print(arr.ndim)
print(arr.size)
print(arr.dtype)
# Out:
# (2, 3)
# 2
# 6
# int64

# %%
# Basic Math

a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
a + b
a * b
np.sin(a)
 
# Matrix Multiplication
A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])
np.dot(A, B)
A @ B
 
# Aggregation
arr = np.array([1, 2, 3, 4])
arr.sum()
arr.mean()
arr.max()
arr.min()
arr.std()
# Out:
# np.float64(1.118033988749895)

# %%
arr = np.array([1, 2, 3, 4, 5])
arr[0]
arr[1:4]
arr[::2]
 
# 2D Arrays
arr = np.array([[1, 2, 3], [4, 5, 6]])
arr[0, 1]
arr[:, 1]
arr[1, :2]
 
# Boolean Indexing
arr = np.array([1, 2, 3, 4, 5])
mask = arr > 3
arr[mask]
# Out:
# array([4, 5])

# %%
# Reshape

arr = np.arange(6)
arr.reshape(2, 3)
 
# Concatenation
a = np.array([1, 2])
b = np.array([3, 4])
np.concatenate((a, b))
 
# Stacking
np.vstack((a, b))
np.hstack((a, b))
# Out:
# array([1, 2, 3, 4])

# %%
a = np.array([1, 2, 3])
a + 5  # [6, 7, 8]
# Out:
# array([6, 7, 8])

# %%
    # Save to a file
np.save('array.npy', arr)
 
# Load from a file
loaded_arr = np.load('array.npy')
